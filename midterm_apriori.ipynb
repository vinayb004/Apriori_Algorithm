# %%
from csv import reader 


def append_data():
    #The purpose is to load the data set and return the dataset that contains a list of transactions and further, each transaction contains several items in it.

    
    print("Hello, welcome to association rule mining\nPlease choose the dataset for which you would like to get the Association rules")
    print("Please type \n1 for Amazon\n2 for BestBuy\n3 for KMART\n4 for Nike\n5 for Custom")
    while True:
        datachoice = input()
        if (datachoice == '1'):
            data ='/Users/VINAY/midterm_datamining_vinay/amazon.csv'
            print('You selected Amazon Dataset')
            break
        elif(datachoice == '2'):
            data = '/Users/VINAY/midterm_datamining_vinay/bestbuy.csv'
            print('You selected BestBuy Dataset')
            break
        elif(datachoice == '3'):
            data = '/Users/VINAY/midterm_datamining_vinay/kmart.csv'
            print('You selected KMART Dataset')
            break
        elif(datachoice == '4'):
            data = '/Users/VINAY/midterm_datamining_vinay/nike.csv'
            print('You selected Nike Dataset')
            break
        elif(datachoice == '5'):
            data = '/Users/VINAY/midterm_datamining_vinay/grocery.csv'
            print('You selected Custom Dataset')
            break
        else:
            print("Please select a valid choice from the above list")
    with open(data, 'r',encoding="windows-1252") as read_obj:
        # pass the file object to reader() to get the reader object
        csv_reader = reader(read_obj)

        # Pass reader object to list() to get a list of lists
        dataset = list(csv_reader)
        for items in dataset:
            for j in range(0, len(items)):
                for items1 in items:

                    if items1 == "":
                        items.remove("")

    return dataset

def gen_Candidate1(dataset):
    # Generate and return a set(dataset) which contains all frequent candidate 1-itemsets.

    Can1 = set()
    for t in dataset:
        for item in t:
            item_set = frozenset([item])
            Can1.add(item_set)
    return Can1


def apriori(Cank_item, Lisk1):
    #To check whether a frequent candidate k-itemset satisfy Apriori property and return true/false accordingly.


    for item in Cank_item:
        sub_Cank = Cank_item - frozenset([item])
        if sub_Cank not in Lisk1:
            return False
    return True


def gen_Cank(Lisk1, k):
    #Generate and return candidate k, a set which contains all frequent candidate k-itemsets.

    Cank = set()
    length_Lisk1 = len(Lisk1)
    listof_Lisk1 = list(Lisk1)
    for i in range(length_Lisk1):
        for j in range(1, length_Lisk1):
            list1 = list(listof_Lisk1[i])
            list2 = list(listof_Lisk1[j])
            list1.sort()
            list2.sort()
            if list1[0:k-2] == list2[0:k-2]:
                Cank_item = listof_Lisk1[i] | listof_Lisk1[j]
                if apriori(Cank_item, Lisk1):
                    Cank.add(Cank_item)
    return Cank


def gen_Lisk(dataset, Cank, minsup, sup_data):
    #Generate and return a list/set which contains all frequent k-itemsets.

    Lisk = set()
    item_count = {}
    for t in dataset:
        for item in Cank:
            if item.issubset(t):
                if item not in item_count:
                    item_count[item] = 1
                else:
                    item_count[item] += 1
    t_num = float(len(dataset))
    for item in item_count:
        if (item_count[item] / t_num) >= minsup:
            Lisk.add(item)
            sup_data[item] = item_count[item] / t_num
    return Lisk


def gen_L(dataset, k, minsup):
    #Generate all frequent itemsets by the value of minimum support’s input.

    sup_data = {}
    Can1 = gen_Candidate1(dataset)
    List1 = gen_Lisk(dataset, Can1, minsup, sup_data)
    Lisksub1 = List1.copy()
    List = []
    List.append(Lisksub1)
    for i in range(2, k+1):
        Ci = gen_Cank(Lisksub1, i)
        Li = gen_Lisk(dataset, Ci, minsup, sup_data)
        Lisksub1 = Li.copy()
        List.append(Lisksub1)
    return List, sup_data


def association_rules(List, sup_data, minconf):
    #Generate and return association rules.

    asso_rules = []
    sublist = []
    for i in range(0, len(List)):
        for freq_set in List[i]:
            for sub_set in sublist:
                if sub_set.issubset(freq_set):
                    conf = sup_data[freq_set] / sup_data[freq_set - sub_set]
                    rule = (freq_set - sub_set, sub_set, conf)
                    if conf >= minconf and rule not in asso_rules:
                        # print freq_set-sub_set, " => ", sub_set, "conf: ", conf
                        asso_rules.append(rule)
            sublist.append(freq_set)
    return asso_rules


if __name__ == "__main__":

    #print("Please enter the min_support")
    #inp = input("Enter the minimum support: ")

    dataset = append_data()
    List, sup_data = gen_L(dataset, k=3, minsup = float(input("Enter the minimum support: ")))
    rules_list = association_rules(List, sup_data, minconf= float(input("Enter the minimum Confidence: ")))
    for Lisk in List:
        print("-*"*40)
        print("frequent " + str(len(list(Lisk)[0])) + "-itemsets\t\tsupport")
        print("-*"*40)
        for freq_set in Lisk:
            print(freq_set, sup_data[freq_set])
    print("\n")
    print("#-"*40)
    print("Association Rules with Confidence")
    print("#-"*40)
    for item in rules_list:
        print(item[0], "=>", item[1], "confidence: ", item[2])
# Out:
# Hello, welcome to association rule mining
# Please choose the dataset for which you would like to get the Association rules
# Please type
# 1 for Amazon
# 2 for BestBuy
# 3 for KMART
# 4 for Nike
# 5 for Custom
# 2
# You selected BestBuy Dataset
# Enter the minimum support: 0.15
# Enter the minimum Confidence: 0.1
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# frequent 1-itemsets		support
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# frozenset({'Anti-Virus'}) 0.7
# frozenset({'External Hard-Drive'}) 0.45
# frozenset({'Printer'}) 0.5
# frozenset({'Flash Drive'}) 0.65
# frozenset({'Microsoft Office'}) 0.55
# frozenset({'Lab Top Case'}) 0.7
# frozenset({'Desk Top'}) 0.3
# frozenset({'Digital Camera'}) 0.45
# frozenset({'Speakers'}) 0.55
# frozenset({'Lab Top'}) 0.6
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# frequent 2-itemsets		support
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# frozenset({'Microsoft Office', 'Anti-Virus'}) 0.4
# frozenset({'External Hard-Drive', 'Anti-Virus'}) 0.45
# frozenset({'Flash Drive', 'Microsoft Office'}) 0.55
# frozenset({'Printer', 'Microsoft Office'}) 0.45
# frozenset({'Lab Top Case', 'Microsoft Office'}) 0.35
# frozenset({'Printer', 'External Hard-Drive'}) 0.25
# frozenset({'Lab Top Case', 'External Hard-Drive'}) 0.4
# frozenset({'Desk Top', 'Microsoft Office'}) 0.25
# frozenset({'Digital Camera', 'Microsoft Office'}) 0.2
# frozenset({'Speakers', 'Desk Top'}) 0.2
# frozenset({'Printer', 'Speakers'}) 0.25
# frozenset({'Lab Top Case', 'Speakers'}) 0.45
# frozenset({'Flash Drive', 'Digital Camera'}) 0.2
# frozenset({'Digital Camera', 'Anti-Virus'}) 0.25
# frozenset({'Speakers', 'Digital Camera'}) 0.35
# frozenset({'Lab Top', 'Speakers'}) 0.25
# frozenset({'Lab Top', 'Digital Camera'}) 0.25
# frozenset({'Lab Top', 'Lab Top Case'}) 0.5
# frozenset({'Lab Top', 'Printer'}) 0.25
# frozenset({'Flash Drive', 'Speakers'}) 0.3
# frozenset({'Lab Top', 'External Hard-Drive'}) 0.3
# frozenset({'Printer', 'Anti-Virus'}) 0.35
# frozenset({'Lab Top Case', 'Anti-Virus'}) 0.6
# frozenset({'Flash Drive', 'Desk Top'}) 0.25
# frozenset({'Speakers', 'Anti-Virus'}) 0.45
# frozenset({'Flash Drive', 'Printer'}) 0.5
# frozenset({'Flash Drive', 'Lab Top Case'}) 0.45
# frozenset({'Flash Drive', 'External Hard-Drive'}) 0.3
# frozenset({'Lab Top Case', 'Printer'}) 0.3
# frozenset({'Microsoft Office', 'External Hard-Drive'}) 0.25
# frozenset({'Printer', 'Desk Top'}) 0.25
# frozenset({'Lab Top Case', 'Desk Top'}) 0.15
# frozenset({'Flash Drive', 'Anti-Virus'}) 0.5
# frozenset({'Printer', 'Digital Camera'}) 0.15
# frozenset({'Desk Top', 'External Hard-Drive'}) 0.15
# frozenset({'Lab Top Case', 'Digital Camera'}) 0.35
# frozenset({'Flash Drive', 'Lab Top'}) 0.35
# frozenset({'Speakers', 'External Hard-Drive'}) 0.3
# frozenset({'Speakers', 'Microsoft Office'}) 0.3
# frozenset({'Lab Top', 'Anti-Virus'}) 0.5
# frozenset({'Digital Camera', 'External Hard-Drive'}) 0.15
# frozenset({'Desk Top', 'Anti-Virus'}) 0.2
# frozenset({'Lab Top', 'Microsoft Office'}) 0.25
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# frequent 3-itemsets		support
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# frozenset({'Printer', 'Desk Top', 'Microsoft Office'}) 0.25
# frozenset({'Speakers', 'Digital Camera', 'External Hard-Drive'}) 0.15
# frozenset({'Flash Drive', 'Microsoft Office', 'Anti-Virus'}) 0.4
# frozenset({'Printer', 'Digital Camera', 'Microsoft Office'}) 0.15
# frozenset({'Lab Top Case', 'Digital Camera', 'Microsoft Office'}) 0.15
# frozenset({'External Hard-Drive', 'Speakers', 'Desk Top'}) 0.15
# frozenset({'Flash Drive', 'Lab Top', 'Microsoft Office'}) 0.25
# frozenset({'Microsoft Office', 'Speakers', 'External Hard-Drive'}) 0.2
# frozenset({'Flash Drive', 'Desk Top', 'Anti-Virus'}) 0.15
# frozenset({'External Hard-Drive', 'Desk Top', 'Anti-Virus'}) 0.15
# frozenset({'Flash Drive', 'Speakers', 'Microsoft Office'}) 0.3
# frozenset({'Flash Drive', 'Printer', 'Digital Camera'}) 0.15
# frozenset({'Flash Drive', 'Lab Top Case', 'Digital Camera'}) 0.15
# frozenset({'Desk Top', 'Speakers', 'Anti-Virus'}) 0.2
# frozenset({'Flash Drive', 'Microsoft Office', 'External Hard-Drive'}) 0.25
# frozenset({'Microsoft Office', 'Desk Top', 'Anti-Virus'}) 0.15
# frozenset({'Printer', 'Lab Top', 'Lab Top Case'}) 0.2
# frozenset({'Flash Drive', 'Speakers', 'External Hard-Drive'}) 0.2
# frozenset({'Flash Drive', 'Lab Top', 'External Hard-Drive'}) 0.15
# frozenset({'Printer', 'Lab Top Case', 'Speakers'}) 0.2
# frozenset({'Lab Top Case', 'Flash Drive', 'Printer'}) 0.3
# frozenset({'Flash Drive', 'Digital Camera', 'Anti-Virus'}) 0.15
# frozenset({'Lab Top Case', 'Speakers', 'Digital Camera'}) 0.3
# frozenset({'Lab Top', 'Lab Top Case', 'Speakers'}) 0.25
# frozenset({'Flash Drive', 'Lab Top', 'Lab Top Case'}) 0.3
# frozenset({'Printer', 'Speakers', 'External Hard-Drive'}) 0.15
# frozenset({'Lab Top Case', 'Speakers', 'External Hard-Drive'}) 0.3
# frozenset({'Flash Drive', 'Lab Top', 'Printer'}) 0.25
# frozenset({'Speakers', 'Digital Camera', 'Anti-Virus'}) 0.25
# frozenset({'Lab Top', 'Printer', 'External Hard-Drive'}) 0.15
# frozenset({'Lab Top', 'Lab Top Case', 'External Hard-Drive'}) 0.25
# frozenset({'Flash Drive', 'Printer', 'Speakers'}) 0.25
# frozenset({'Flash Drive', 'Lab Top Case', 'Speakers'}) 0.25
# frozenset({'Microsoft Office', 'Digital Camera', 'Anti-Virus'}) 0.15
# frozenset({'Microsoft Office', 'Printer', 'External Hard-Drive'}) 0.2
# frozenset({'Microsoft Office', 'Lab Top Case', 'External Hard-Drive'}) 0.25
# frozenset({'Lab Top', 'Speakers', 'Digital Camera'}) 0.2
# frozenset({'Desk Top', 'Printer', 'Anti-Virus'}) 0.15
# frozenset({'Lab Top', 'Lab Top Case', 'Microsoft Office'}) 0.2
# frozenset({'Lab Top', 'Printer', 'Microsoft Office'}) 0.2
# frozenset({'Desk Top', 'Lab Top Case', 'Anti-Virus'}) 0.15
# frozenset({'Printer', 'Speakers', 'Microsoft Office'}) 0.25
# frozenset({'Microsoft Office', 'Printer', 'Anti-Virus'}) 0.3
# frozenset({'Microsoft Office', 'Lab Top Case', 'Anti-Virus'}) 0.35
# frozenset({'Flash Drive', 'Desk Top', 'Microsoft Office'}) 0.25
# frozenset({'Lab Top Case', 'Speakers', 'Microsoft Office'}) 0.25
# frozenset({'External Hard-Drive', 'Speakers', 'Anti-Virus'}) 0.3
# frozenset({'External Hard-Drive', 'Lab Top', 'Anti-Virus'}) 0.3
# frozenset({'Printer', 'Lab Top Case', 'Microsoft Office'}) 0.25
# frozenset({'Flash Drive', 'Printer', 'Microsoft Office'}) 0.45
# frozenset({'Speakers', 'Digital Camera', 'Microsoft Office'}) 0.15
# frozenset({'Lab Top Case', 'Digital Camera', 'External Hard-Drive'}) 0.15
# frozenset({'Microsoft Office', 'Lab Top', 'Anti-Virus'}) 0.2
# frozenset({'External Hard-Drive', 'Printer', 'Anti-Virus'}) 0.25
# frozenset({'External Hard-Drive', 'Lab Top Case', 'Anti-Virus'}) 0.4
# frozenset({'Microsoft Office', 'Speakers', 'Anti-Virus'}) 0.3
# frozenset({'Lab Top', 'Speakers', 'External Hard-Drive'}) 0.15
# frozenset({'Lab Top Case', 'Digital Camera', 'Anti-Virus'}) 0.25
# frozenset({'Lab Top Case', 'Printer', 'External Hard-Drive'}) 0.25
# frozenset({'Flash Drive', 'Lab Top', 'Anti-Virus'}) 0.3
# frozenset({'Lab Top', 'Lab Top Case', 'Digital Camera'}) 0.25
# frozenset({'Flash Drive', 'Speakers', 'Anti-Virus'}) 0.3
# frozenset({'Printer', 'Speakers', 'Desk Top'}) 0.15
# frozenset({'Lab Top Case', 'Speakers', 'Desk Top'}) 0.15
# frozenset({'Lab Top Case', 'Printer', 'Anti-Virus'}) 0.3
# frozenset({'Lab Top', 'Digital Camera', 'Anti-Virus'}) 0.2
# frozenset({'Flash Drive', 'Printer', 'Desk Top'}) 0.25
# frozenset({'Lab Top', 'Speakers', 'Anti-Virus'}) 0.25
# frozenset({'Flash Drive', 'Printer', 'Anti-Virus'}) 0.35
# frozenset({'Flash Drive', 'Lab Top Case', 'Anti-Virus'}) 0.45
# frozenset({'Lab Top', 'Lab Top Case', 'Anti-Virus'}) 0.45
# frozenset({'Lab Top', 'Printer', 'Anti-Virus'}) 0.2
# frozenset({'Flash Drive', 'Speakers', 'Desk Top'}) 0.15
# frozenset({'Flash Drive', 'Speakers', 'Digital Camera'}) 0.15
# frozenset({'Printer', 'Speakers', 'Anti-Virus'}) 0.25
# frozenset({'Lab Top Case', 'Speakers', 'Anti-Virus'}) 0.4
# frozenset({'Flash Drive', 'Digital Camera', 'Microsoft Office'}) 0.2
# frozenset({'External Hard-Drive', 'Microsoft Office', 'Anti-Virus'}) 0.25
# frozenset({'External Hard-Drive', 'Digital Camera', 'Anti-Virus'}) 0.15
# frozenset({'Flash Drive', 'Printer', 'External Hard-Drive'}) 0.25
# frozenset({'Flash Drive', 'Lab Top Case', 'External Hard-Drive'}) 0.3
# frozenset({'External Hard-Drive', 'Lab Top Case', 'Desk Top'}) 0.15
# frozenset({'External Hard-Drive', 'Flash Drive', 'Anti-Virus'}) 0.3
# frozenset({'Desk Top', 'Speakers', 'Microsoft Office'}) 0.15
# frozenset({'Flash Drive', 'Lab Top Case', 'Microsoft Office'}) 0.35
#
#
# #-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-
# Association Rules with Confidence
# #-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-
# frozenset({'Microsoft Office'}) => frozenset({'Anti-Virus'}) confidence:  0.7272727272727273
# frozenset({'Anti-Virus'}) => frozenset({'Microsoft Office'}) confidence:  0.5714285714285715
# frozenset({'External Hard-Drive'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Anti-Virus'}) => frozenset({'External Hard-Drive'}) confidence:  0.6428571428571429
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive'}) => frozenset({'Microsoft Office'}) confidence:  0.8461538461538461
# frozenset({'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.8181818181818181
# frozenset({'Printer'}) => frozenset({'Microsoft Office'}) confidence:  0.9
# frozenset({'Lab Top Case'}) => frozenset({'Microsoft Office'}) confidence:  0.5
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  0.6363636363636362
# frozenset({'Printer'}) => frozenset({'External Hard-Drive'}) confidence:  0.5
# frozenset({'External Hard-Drive'}) => frozenset({'Printer'}) confidence:  0.5555555555555556
# frozenset({'Lab Top Case'}) => frozenset({'External Hard-Drive'}) confidence:  0.5714285714285715
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top Case'}) confidence:  0.888888888888889
# frozenset({'Desk Top'}) => frozenset({'Microsoft Office'}) confidence:  0.8333333333333334
# frozenset({'Microsoft Office'}) => frozenset({'Desk Top'}) confidence:  0.45454545454545453
# frozenset({'Digital Camera'}) => frozenset({'Microsoft Office'}) confidence:  0.4444444444444445
# frozenset({'Microsoft Office'}) => frozenset({'Digital Camera'}) confidence:  0.36363636363636365
# frozenset({'Speakers'}) => frozenset({'Desk Top'}) confidence:  0.36363636363636365
# frozenset({'Desk Top'}) => frozenset({'Speakers'}) confidence:  0.6666666666666667
# frozenset({'Speakers'}) => frozenset({'Printer'}) confidence:  0.45454545454545453
# frozenset({'Printer'}) => frozenset({'Speakers'}) confidence:  0.5
# frozenset({'Speakers'}) => frozenset({'Lab Top Case'}) confidence:  0.8181818181818181
# frozenset({'Lab Top Case'}) => frozenset({'Speakers'}) confidence:  0.6428571428571429
# frozenset({'Digital Camera'}) => frozenset({'Flash Drive'}) confidence:  0.4444444444444445
# frozenset({'Flash Drive'}) => frozenset({'Digital Camera'}) confidence:  0.3076923076923077
# frozenset({'Digital Camera'}) => frozenset({'Anti-Virus'}) confidence:  0.5555555555555556
# frozenset({'Anti-Virus'}) => frozenset({'Digital Camera'}) confidence:  0.35714285714285715
# frozenset({'Speakers'}) => frozenset({'Digital Camera'}) confidence:  0.6363636363636362
# frozenset({'Digital Camera'}) => frozenset({'Speakers'}) confidence:  0.7777777777777777
# frozenset({'Lab Top'}) => frozenset({'Speakers'}) confidence:  0.4166666666666667
# frozenset({'Speakers'}) => frozenset({'Lab Top'}) confidence:  0.45454545454545453
# frozenset({'Lab Top'}) => frozenset({'Digital Camera'}) confidence:  0.4166666666666667
# frozenset({'Digital Camera'}) => frozenset({'Lab Top'}) confidence:  0.5555555555555556
# frozenset({'Lab Top'}) => frozenset({'Lab Top Case'}) confidence:  0.8333333333333334
# frozenset({'Lab Top Case'}) => frozenset({'Lab Top'}) confidence:  0.7142857142857143
# frozenset({'Lab Top'}) => frozenset({'Printer'}) confidence:  0.4166666666666667
# frozenset({'Printer'}) => frozenset({'Lab Top'}) confidence:  0.5
# frozenset({'Speakers'}) => frozenset({'Flash Drive'}) confidence:  0.5454545454545454
# frozenset({'Flash Drive'}) => frozenset({'Speakers'}) confidence:  0.4615384615384615
# frozenset({'Lab Top'}) => frozenset({'External Hard-Drive'}) confidence:  0.5
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top'}) confidence:  0.6666666666666666
# frozenset({'Printer'}) => frozenset({'Anti-Virus'}) confidence:  0.7
# frozenset({'Anti-Virus'}) => frozenset({'Printer'}) confidence:  0.5
# frozenset({'Lab Top Case'}) => frozenset({'Anti-Virus'}) confidence:  0.8571428571428572
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top Case'}) confidence:  0.8571428571428572
# frozenset({'Desk Top'}) => frozenset({'Flash Drive'}) confidence:  0.8333333333333334
# frozenset({'Flash Drive'}) => frozenset({'Desk Top'}) confidence:  0.3846153846153846
# frozenset({'Speakers'}) => frozenset({'Anti-Virus'}) confidence:  0.8181818181818181
# frozenset({'Anti-Virus'}) => frozenset({'Speakers'}) confidence:  0.6428571428571429
# frozenset({'Flash Drive'}) => frozenset({'Printer'}) confidence:  0.7692307692307692
# frozenset({'Printer'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive'}) confidence:  0.6428571428571429
# frozenset({'Flash Drive'}) => frozenset({'Lab Top Case'}) confidence:  0.6923076923076923
# frozenset({'Flash Drive'}) => frozenset({'External Hard-Drive'}) confidence:  0.4615384615384615
# frozenset({'External Hard-Drive'}) => frozenset({'Flash Drive'}) confidence:  0.6666666666666666
# frozenset({'Lab Top Case'}) => frozenset({'Printer'}) confidence:  0.4285714285714286
# frozenset({'Printer'}) => frozenset({'Lab Top Case'}) confidence:  0.6
# frozenset({'Microsoft Office'}) => frozenset({'External Hard-Drive'}) confidence:  0.45454545454545453
# frozenset({'External Hard-Drive'}) => frozenset({'Microsoft Office'}) confidence:  0.5555555555555556
# frozenset({'Desk Top'}) => frozenset({'Printer'}) confidence:  0.8333333333333334
# frozenset({'Printer'}) => frozenset({'Desk Top'}) confidence:  0.5
# frozenset({'Desk Top'}) => frozenset({'Lab Top Case'}) confidence:  0.5
# frozenset({'Lab Top Case'}) => frozenset({'Desk Top'}) confidence:  0.2142857142857143
# frozenset({'Flash Drive'}) => frozenset({'Anti-Virus'}) confidence:  0.7692307692307692
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive'}) confidence:  0.7142857142857143
# frozenset({'Digital Camera'}) => frozenset({'Printer'}) confidence:  0.3333333333333333
# frozenset({'Printer'}) => frozenset({'Digital Camera'}) confidence:  0.3
# frozenset({'Desk Top'}) => frozenset({'External Hard-Drive'}) confidence:  0.5
# frozenset({'External Hard-Drive'}) => frozenset({'Desk Top'}) confidence:  0.3333333333333333
# frozenset({'Digital Camera'}) => frozenset({'Lab Top Case'}) confidence:  0.7777777777777777
# frozenset({'Lab Top Case'}) => frozenset({'Digital Camera'}) confidence:  0.5
# frozenset({'Lab Top'}) => frozenset({'Flash Drive'}) confidence:  0.5833333333333334
# frozenset({'Flash Drive'}) => frozenset({'Lab Top'}) confidence:  0.5384615384615384
# frozenset({'Speakers'}) => frozenset({'External Hard-Drive'}) confidence:  0.5454545454545454
# frozenset({'External Hard-Drive'}) => frozenset({'Speakers'}) confidence:  0.6666666666666666
# frozenset({'Speakers'}) => frozenset({'Microsoft Office'}) confidence:  0.5454545454545454
# frozenset({'Microsoft Office'}) => frozenset({'Speakers'}) confidence:  0.5454545454545454
# frozenset({'Lab Top'}) => frozenset({'Anti-Virus'}) confidence:  0.8333333333333334
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top'}) confidence:  0.7142857142857143
# frozenset({'Digital Camera'}) => frozenset({'External Hard-Drive'}) confidence:  0.3333333333333333
# frozenset({'External Hard-Drive'}) => frozenset({'Digital Camera'}) confidence:  0.3333333333333333
# frozenset({'Desk Top'}) => frozenset({'Anti-Virus'}) confidence:  0.6666666666666667
# frozenset({'Anti-Virus'}) => frozenset({'Desk Top'}) confidence:  0.28571428571428575
# frozenset({'Lab Top'}) => frozenset({'Microsoft Office'}) confidence:  0.4166666666666667
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top'}) confidence:  0.45454545454545453
# frozenset({'Microsoft Office', 'Desk Top'}) => frozenset({'Printer'}) confidence:  1.0
# frozenset({'Printer', 'Desk Top'}) => frozenset({'Microsoft Office'}) confidence:  1.0
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'Desk Top'}) confidence:  0.5555555555555556
# frozenset({'Desk Top'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.8333333333333334
# frozenset({'Printer'}) => frozenset({'Desk Top', 'Microsoft Office'}) confidence:  0.5
# frozenset({'Microsoft Office'}) => frozenset({'Printer', 'Desk Top'}) confidence:  0.45454545454545453
# frozenset({'Speakers', 'Digital Camera'}) => frozenset({'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'Speakers', 'External Hard-Drive'}) => frozenset({'Digital Camera'}) confidence:  0.5
# frozenset({'Digital Camera', 'External Hard-Drive'}) => frozenset({'Speakers'}) confidence:  1.0
# frozenset({'External Hard-Drive'}) => frozenset({'Speakers', 'Digital Camera'}) confidence:  0.3333333333333333
# frozenset({'Digital Camera'}) => frozenset({'Speakers', 'External Hard-Drive'}) confidence:  0.3333333333333333
# frozenset({'Speakers'}) => frozenset({'Digital Camera', 'External Hard-Drive'}) confidence:  0.2727272727272727
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'Anti-Virus'}) confidence:  0.7272727272727273
# frozenset({'Anti-Virus', 'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'Microsoft Office'}) confidence:  0.8
# frozenset({'Flash Drive'}) => frozenset({'Microsoft Office', 'Anti-Virus'}) confidence:  0.6153846153846154
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.5714285714285715
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.7272727272727273
# frozenset({'Digital Camera', 'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.7499999999999999
# frozenset({'Printer', 'Digital Camera'}) => frozenset({'Microsoft Office'}) confidence:  1.0
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'Digital Camera'}) confidence:  0.3333333333333333
# frozenset({'Digital Camera'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.3333333333333333
# frozenset({'Printer'}) => frozenset({'Digital Camera', 'Microsoft Office'}) confidence:  0.3
# frozenset({'Microsoft Office'}) => frozenset({'Printer', 'Digital Camera'}) confidence:  0.2727272727272727
# frozenset({'Lab Top Case', 'Digital Camera'}) => frozenset({'Microsoft Office'}) confidence:  0.4285714285714286
# frozenset({'Digital Camera', 'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  0.7499999999999999
# frozenset({'Lab Top Case', 'Microsoft Office'}) => frozenset({'Digital Camera'}) confidence:  0.4285714285714286
# frozenset({'Digital Camera'}) => frozenset({'Lab Top Case', 'Microsoft Office'}) confidence:  0.3333333333333333
# frozenset({'Lab Top Case'}) => frozenset({'Digital Camera', 'Microsoft Office'}) confidence:  0.2142857142857143
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top Case', 'Digital Camera'}) confidence:  0.2727272727272727
# frozenset({'Speakers', 'Desk Top'}) => frozenset({'External Hard-Drive'}) confidence:  0.7499999999999999
# frozenset({'Speakers', 'External Hard-Drive'}) => frozenset({'Desk Top'}) confidence:  0.5
# frozenset({'Desk Top', 'External Hard-Drive'}) => frozenset({'Speakers'}) confidence:  1.0
# frozenset({'External Hard-Drive'}) => frozenset({'Speakers', 'Desk Top'}) confidence:  0.3333333333333333
# frozenset({'Speakers'}) => frozenset({'Desk Top', 'External Hard-Drive'}) confidence:  0.2727272727272727
# frozenset({'Desk Top'}) => frozenset({'Speakers', 'External Hard-Drive'}) confidence:  0.5
# frozenset({'Lab Top', 'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Lab Top'}) => frozenset({'Microsoft Office'}) confidence:  0.7142857142857143
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'Lab Top'}) confidence:  0.45454545454545453
# frozenset({'Lab Top'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.4166666666666667
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'Lab Top'}) confidence:  0.45454545454545453
# frozenset({'Flash Drive'}) => frozenset({'Lab Top', 'Microsoft Office'}) confidence:  0.3846153846153846
# frozenset({'Speakers', 'Microsoft Office'}) => frozenset({'External Hard-Drive'}) confidence:  0.6666666666666667
# frozenset({'Speakers', 'External Hard-Drive'}) => frozenset({'Microsoft Office'}) confidence:  0.6666666666666667
# frozenset({'External Hard-Drive', 'Microsoft Office'}) => frozenset({'Speakers'}) confidence:  0.8
# frozenset({'Speakers'}) => frozenset({'Microsoft Office', 'External Hard-Drive'}) confidence:  0.36363636363636365
# frozenset({'Microsoft Office'}) => frozenset({'Speakers', 'External Hard-Drive'}) confidence:  0.36363636363636365
# frozenset({'External Hard-Drive'}) => frozenset({'Speakers', 'Microsoft Office'}) confidence:  0.4444444444444445
# frozenset({'Flash Drive', 'Desk Top'}) => frozenset({'Anti-Virus'}) confidence:  0.6
# frozenset({'Anti-Virus', 'Desk Top'}) => frozenset({'Flash Drive'}) confidence:  0.7499999999999999
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'Desk Top'}) confidence:  0.3
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'Desk Top'}) confidence:  0.2142857142857143
# frozenset({'Desk Top'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Flash Drive'}) => frozenset({'Desk Top', 'Anti-Virus'}) confidence:  0.23076923076923075
# frozenset({'Desk Top', 'External Hard-Drive'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Anti-Virus', 'Desk Top'}) => frozenset({'External Hard-Drive'}) confidence:  0.7499999999999999
# frozenset({'Anti-Virus', 'External Hard-Drive'}) => frozenset({'Desk Top'}) confidence:  0.3333333333333333
# frozenset({'Desk Top'}) => frozenset({'External Hard-Drive', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Anti-Virus'}) => frozenset({'Desk Top', 'External Hard-Drive'}) confidence:  0.2142857142857143
# frozenset({'External Hard-Drive'}) => frozenset({'Desk Top', 'Anti-Virus'}) confidence:  0.3333333333333333
# frozenset({'Speakers', 'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Speakers'}) => frozenset({'Microsoft Office'}) confidence:  1.0
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'Speakers'}) confidence:  0.5454545454545454
# frozenset({'Speakers'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.5454545454545454
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'Speakers'}) confidence:  0.5454545454545454
# frozenset({'Flash Drive'}) => frozenset({'Speakers', 'Microsoft Office'}) confidence:  0.4615384615384615
# frozenset({'Flash Drive', 'Digital Camera'}) => frozenset({'Printer'}) confidence:  0.7499999999999999
# frozenset({'Printer', 'Digital Camera'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'Digital Camera'}) confidence:  0.3
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'Digital Camera'}) confidence:  0.3
# frozenset({'Digital Camera'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.3333333333333333
# frozenset({'Flash Drive'}) => frozenset({'Printer', 'Digital Camera'}) confidence:  0.23076923076923075
# frozenset({'Lab Top Case', 'Digital Camera'}) => frozenset({'Flash Drive'}) confidence:  0.4285714285714286
# frozenset({'Flash Drive', 'Digital Camera'}) => frozenset({'Lab Top Case'}) confidence:  0.7499999999999999
# frozenset({'Flash Drive', 'Lab Top Case'}) => frozenset({'Digital Camera'}) confidence:  0.3333333333333333
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive', 'Digital Camera'}) confidence:  0.2142857142857143
# frozenset({'Digital Camera'}) => frozenset({'Flash Drive', 'Lab Top Case'}) confidence:  0.3333333333333333
# frozenset({'Flash Drive'}) => frozenset({'Lab Top Case', 'Digital Camera'}) confidence:  0.23076923076923075
# frozenset({'Speakers', 'Desk Top'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Speakers', 'Anti-Virus'}) => frozenset({'Desk Top'}) confidence:  0.4444444444444445
# frozenset({'Anti-Virus', 'Desk Top'}) => frozenset({'Speakers'}) confidence:  1.0
# frozenset({'Anti-Virus'}) => frozenset({'Speakers', 'Desk Top'}) confidence:  0.28571428571428575
# frozenset({'Desk Top'}) => frozenset({'Speakers', 'Anti-Virus'}) confidence:  0.6666666666666667
# frozenset({'Speakers'}) => frozenset({'Desk Top', 'Anti-Virus'}) confidence:  0.36363636363636365
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'External Hard-Drive'}) confidence:  0.45454545454545453
# frozenset({'External Hard-Drive', 'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'External Hard-Drive'}) => frozenset({'Microsoft Office'}) confidence:  0.8333333333333334
# frozenset({'External Hard-Drive'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.5555555555555556
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'External Hard-Drive'}) confidence:  0.45454545454545453
# frozenset({'Flash Drive'}) => frozenset({'Microsoft Office', 'External Hard-Drive'}) confidence:  0.3846153846153846
# frozenset({'Desk Top', 'Microsoft Office'}) => frozenset({'Anti-Virus'}) confidence:  0.6
# frozenset({'Anti-Virus', 'Desk Top'}) => frozenset({'Microsoft Office'}) confidence:  0.7499999999999999
# frozenset({'Anti-Virus', 'Microsoft Office'}) => frozenset({'Desk Top'}) confidence:  0.37499999999999994
# frozenset({'Desk Top'}) => frozenset({'Microsoft Office', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Anti-Virus'}) => frozenset({'Desk Top', 'Microsoft Office'}) confidence:  0.2142857142857143
# frozenset({'Microsoft Office'}) => frozenset({'Desk Top', 'Anti-Virus'}) confidence:  0.2727272727272727
# frozenset({'Lab Top', 'Lab Top Case'}) => frozenset({'Printer'}) confidence:  0.4
# frozenset({'Lab Top', 'Printer'}) => frozenset({'Lab Top Case'}) confidence:  0.8
# frozenset({'Lab Top Case', 'Printer'}) => frozenset({'Lab Top'}) confidence:  0.6666666666666667
# frozenset({'Printer'}) => frozenset({'Lab Top', 'Lab Top Case'}) confidence:  0.4
# frozenset({'Lab Top Case'}) => frozenset({'Lab Top', 'Printer'}) confidence:  0.28571428571428575
# frozenset({'Lab Top'}) => frozenset({'Lab Top Case', 'Printer'}) confidence:  0.33333333333333337
# frozenset({'Flash Drive', 'Speakers'}) => frozenset({'External Hard-Drive'}) confidence:  0.6666666666666667
# frozenset({'Speakers', 'External Hard-Drive'}) => frozenset({'Flash Drive'}) confidence:  0.6666666666666667
# frozenset({'Flash Drive', 'External Hard-Drive'}) => frozenset({'Speakers'}) confidence:  0.6666666666666667
# frozenset({'External Hard-Drive'}) => frozenset({'Flash Drive', 'Speakers'}) confidence:  0.4444444444444445
# frozenset({'Speakers'}) => frozenset({'Flash Drive', 'External Hard-Drive'}) confidence:  0.36363636363636365
# frozenset({'Flash Drive'}) => frozenset({'Speakers', 'External Hard-Drive'}) confidence:  0.3076923076923077
# frozenset({'Flash Drive', 'Lab Top'}) => frozenset({'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'Lab Top', 'External Hard-Drive'}) => frozenset({'Flash Drive'}) confidence:  0.5
# frozenset({'Flash Drive', 'External Hard-Drive'}) => frozenset({'Lab Top'}) confidence:  0.5
# frozenset({'Flash Drive'}) => frozenset({'Lab Top', 'External Hard-Drive'}) confidence:  0.23076923076923075
# frozenset({'Lab Top'}) => frozenset({'Flash Drive', 'External Hard-Drive'}) confidence:  0.25
# frozenset({'External Hard-Drive'}) => frozenset({'Flash Drive', 'Lab Top'}) confidence:  0.3333333333333333
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'Printer'}) confidence:  0.4444444444444445
# frozenset({'Printer', 'Speakers'}) => frozenset({'Lab Top Case'}) confidence:  0.8
# frozenset({'Lab Top Case', 'Printer'}) => frozenset({'Speakers'}) confidence:  0.6666666666666667
# frozenset({'Lab Top Case'}) => frozenset({'Printer', 'Speakers'}) confidence:  0.28571428571428575
# frozenset({'Printer'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.4
# frozenset({'Speakers'}) => frozenset({'Lab Top Case', 'Printer'}) confidence:  0.36363636363636365
# frozenset({'Flash Drive', 'Lab Top Case'}) => frozenset({'Printer'}) confidence:  0.6666666666666666
# frozenset({'Printer', 'Lab Top Case'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'Lab Top Case'}) confidence:  0.6
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.4285714285714286
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'Lab Top Case'}) confidence:  0.6
# frozenset({'Flash Drive'}) => frozenset({'Lab Top Case', 'Printer'}) confidence:  0.4615384615384615
# frozenset({'Flash Drive', 'Digital Camera'}) => frozenset({'Anti-Virus'}) confidence:  0.7499999999999999
# frozenset({'Digital Camera', 'Anti-Virus'}) => frozenset({'Flash Drive'}) confidence:  0.6
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'Digital Camera'}) confidence:  0.3
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'Digital Camera'}) confidence:  0.2142857142857143
# frozenset({'Flash Drive'}) => frozenset({'Digital Camera', 'Anti-Virus'}) confidence:  0.23076923076923075
# frozenset({'Digital Camera'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.3333333333333333
# frozenset({'Speakers', 'Digital Camera'}) => frozenset({'Lab Top Case'}) confidence:  0.8571428571428572
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'Digital Camera'}) confidence:  0.6666666666666666
# frozenset({'Lab Top Case', 'Digital Camera'}) => frozenset({'Speakers'}) confidence:  0.8571428571428572
# frozenset({'Digital Camera'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.6666666666666666
# frozenset({'Lab Top Case'}) => frozenset({'Speakers', 'Digital Camera'}) confidence:  0.4285714285714286
# frozenset({'Speakers'}) => frozenset({'Lab Top Case', 'Digital Camera'}) confidence:  0.5454545454545454
# frozenset({'Lab Top', 'Speakers'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'Lab Top', 'Lab Top Case'}) => frozenset({'Speakers'}) confidence:  0.5
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'Lab Top'}) confidence:  0.5555555555555556
# frozenset({'Lab Top'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.4166666666666667
# frozenset({'Lab Top Case'}) => frozenset({'Lab Top', 'Speakers'}) confidence:  0.35714285714285715
# frozenset({'Speakers'}) => frozenset({'Lab Top', 'Lab Top Case'}) confidence:  0.45454545454545453
# frozenset({'Lab Top', 'Lab Top Case'}) => frozenset({'Flash Drive'}) confidence:  0.6
# frozenset({'Flash Drive', 'Lab Top'}) => frozenset({'Lab Top Case'}) confidence:  0.8571428571428572
# frozenset({'Flash Drive', 'Lab Top Case'}) => frozenset({'Lab Top'}) confidence:  0.6666666666666666
# frozenset({'Flash Drive'}) => frozenset({'Lab Top', 'Lab Top Case'}) confidence:  0.4615384615384615
# frozenset({'Lab Top'}) => frozenset({'Flash Drive', 'Lab Top Case'}) confidence:  0.5
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive', 'Lab Top'}) confidence:  0.4285714285714286
# frozenset({'Printer', 'Speakers'}) => frozenset({'External Hard-Drive'}) confidence:  0.6
# frozenset({'Speakers', 'External Hard-Drive'}) => frozenset({'Printer'}) confidence:  0.5
# frozenset({'Printer', 'External Hard-Drive'}) => frozenset({'Speakers'}) confidence:  0.6
# frozenset({'Speakers'}) => frozenset({'Printer', 'External Hard-Drive'}) confidence:  0.2727272727272727
# frozenset({'External Hard-Drive'}) => frozenset({'Printer', 'Speakers'}) confidence:  0.3333333333333333
# frozenset({'Printer'}) => frozenset({'Speakers', 'External Hard-Drive'}) confidence:  0.3
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'External Hard-Drive'}) confidence:  0.6666666666666666
# frozenset({'Speakers', 'External Hard-Drive'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'Lab Top Case', 'External Hard-Drive'}) => frozenset({'Speakers'}) confidence:  0.7499999999999999
# frozenset({'Speakers'}) => frozenset({'Lab Top Case', 'External Hard-Drive'}) confidence:  0.5454545454545454
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.6666666666666666
# frozenset({'Lab Top Case'}) => frozenset({'Speakers', 'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'Flash Drive', 'Lab Top'}) => frozenset({'Printer'}) confidence:  0.7142857142857143
# frozenset({'Lab Top', 'Printer'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'Lab Top'}) confidence:  0.5
# frozenset({'Flash Drive'}) => frozenset({'Lab Top', 'Printer'}) confidence:  0.3846153846153846
# frozenset({'Lab Top'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.4166666666666667
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'Lab Top'}) confidence:  0.5
# frozenset({'Speakers', 'Digital Camera'}) => frozenset({'Anti-Virus'}) confidence:  0.7142857142857143
# frozenset({'Speakers', 'Anti-Virus'}) => frozenset({'Digital Camera'}) confidence:  0.5555555555555556
# frozenset({'Digital Camera', 'Anti-Virus'}) => frozenset({'Speakers'}) confidence:  1.0
# frozenset({'Speakers'}) => frozenset({'Digital Camera', 'Anti-Virus'}) confidence:  0.45454545454545453
# frozenset({'Anti-Virus'}) => frozenset({'Speakers', 'Digital Camera'}) confidence:  0.35714285714285715
# frozenset({'Digital Camera'}) => frozenset({'Speakers', 'Anti-Virus'}) confidence:  0.5555555555555556
# frozenset({'Lab Top', 'Printer'}) => frozenset({'External Hard-Drive'}) confidence:  0.6
# frozenset({'Lab Top', 'External Hard-Drive'}) => frozenset({'Printer'}) confidence:  0.5
# frozenset({'Printer', 'External Hard-Drive'}) => frozenset({'Lab Top'}) confidence:  0.6
# frozenset({'Lab Top'}) => frozenset({'Printer', 'External Hard-Drive'}) confidence:  0.25
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top', 'Printer'}) confidence:  0.3333333333333333
# frozenset({'Printer'}) => frozenset({'Lab Top', 'External Hard-Drive'}) confidence:  0.3
# frozenset({'Lab Top', 'Lab Top Case'}) => frozenset({'External Hard-Drive'}) confidence:  0.5
# frozenset({'Lab Top', 'External Hard-Drive'}) => frozenset({'Lab Top Case'}) confidence:  0.8333333333333334
# frozenset({'Lab Top Case', 'External Hard-Drive'}) => frozenset({'Lab Top'}) confidence:  0.625
# frozenset({'Lab Top'}) => frozenset({'Lab Top Case', 'External Hard-Drive'}) confidence:  0.4166666666666667
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top', 'Lab Top Case'}) confidence:  0.5555555555555556
# frozenset({'Lab Top Case'}) => frozenset({'Lab Top', 'External Hard-Drive'}) confidence:  0.35714285714285715
# frozenset({'Flash Drive', 'Speakers'}) => frozenset({'Printer'}) confidence:  0.8333333333333334
# frozenset({'Printer', 'Speakers'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'Speakers'}) confidence:  0.5
# frozenset({'Flash Drive'}) => frozenset({'Printer', 'Speakers'}) confidence:  0.3846153846153846
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'Speakers'}) confidence:  0.5
# frozenset({'Speakers'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.45454545454545453
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'Flash Drive'}) confidence:  0.5555555555555556
# frozenset({'Flash Drive', 'Speakers'}) => frozenset({'Lab Top Case'}) confidence:  0.8333333333333334
# frozenset({'Flash Drive', 'Lab Top Case'}) => frozenset({'Speakers'}) confidence:  0.5555555555555556
# frozenset({'Flash Drive'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.3846153846153846
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive', 'Speakers'}) confidence:  0.35714285714285715
# frozenset({'Speakers'}) => frozenset({'Flash Drive', 'Lab Top Case'}) confidence:  0.45454545454545453
# frozenset({'Digital Camera', 'Microsoft Office'}) => frozenset({'Anti-Virus'}) confidence:  0.7499999999999999
# frozenset({'Digital Camera', 'Anti-Virus'}) => frozenset({'Microsoft Office'}) confidence:  0.6
# frozenset({'Anti-Virus', 'Microsoft Office'}) => frozenset({'Digital Camera'}) confidence:  0.37499999999999994
# frozenset({'Digital Camera'}) => frozenset({'Microsoft Office', 'Anti-Virus'}) confidence:  0.3333333333333333
# frozenset({'Anti-Virus'}) => frozenset({'Digital Camera', 'Microsoft Office'}) confidence:  0.2142857142857143
# frozenset({'Microsoft Office'}) => frozenset({'Digital Camera', 'Anti-Virus'}) confidence:  0.2727272727272727
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'External Hard-Drive'}) confidence:  0.4444444444444445
# frozenset({'External Hard-Drive', 'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.8
# frozenset({'Printer', 'External Hard-Drive'}) => frozenset({'Microsoft Office'}) confidence:  0.8
# frozenset({'External Hard-Drive'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.4444444444444445
# frozenset({'Microsoft Office'}) => frozenset({'Printer', 'External Hard-Drive'}) confidence:  0.36363636363636365
# frozenset({'Printer'}) => frozenset({'Microsoft Office', 'External Hard-Drive'}) confidence:  0.4
# frozenset({'Lab Top Case', 'Microsoft Office'}) => frozenset({'External Hard-Drive'}) confidence:  0.7142857142857143
# frozenset({'Lab Top Case', 'External Hard-Drive'}) => frozenset({'Microsoft Office'}) confidence:  0.625
# frozenset({'External Hard-Drive', 'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top Case', 'Microsoft Office'}) confidence:  0.5555555555555556
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top Case', 'External Hard-Drive'}) confidence:  0.45454545454545453
# frozenset({'Lab Top Case'}) => frozenset({'Microsoft Office', 'External Hard-Drive'}) confidence:  0.35714285714285715
# frozenset({'Lab Top', 'Speakers'}) => frozenset({'Digital Camera'}) confidence:  0.8
# frozenset({'Lab Top', 'Digital Camera'}) => frozenset({'Speakers'}) confidence:  0.8
# frozenset({'Speakers', 'Digital Camera'}) => frozenset({'Lab Top'}) confidence:  0.5714285714285715
# frozenset({'Lab Top'}) => frozenset({'Speakers', 'Digital Camera'}) confidence:  0.33333333333333337
# frozenset({'Digital Camera'}) => frozenset({'Lab Top', 'Speakers'}) confidence:  0.4444444444444445
# frozenset({'Speakers'}) => frozenset({'Lab Top', 'Digital Camera'}) confidence:  0.36363636363636365
# frozenset({'Printer', 'Desk Top'}) => frozenset({'Anti-Virus'}) confidence:  0.6
# frozenset({'Anti-Virus', 'Desk Top'}) => frozenset({'Printer'}) confidence:  0.7499999999999999
# frozenset({'Printer', 'Anti-Virus'}) => frozenset({'Desk Top'}) confidence:  0.4285714285714286
# frozenset({'Desk Top'}) => frozenset({'Printer', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Anti-Virus'}) => frozenset({'Printer', 'Desk Top'}) confidence:  0.2142857142857143
# frozenset({'Printer'}) => frozenset({'Desk Top', 'Anti-Virus'}) confidence:  0.3
# frozenset({'Lab Top', 'Lab Top Case'}) => frozenset({'Microsoft Office'}) confidence:  0.4
# frozenset({'Lab Top', 'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  0.8
# frozenset({'Lab Top Case', 'Microsoft Office'}) => frozenset({'Lab Top'}) confidence:  0.5714285714285715
# frozenset({'Lab Top'}) => frozenset({'Lab Top Case', 'Microsoft Office'}) confidence:  0.33333333333333337
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top', 'Lab Top Case'}) confidence:  0.36363636363636365
# frozenset({'Lab Top Case'}) => frozenset({'Lab Top', 'Microsoft Office'}) confidence:  0.28571428571428575
# frozenset({'Lab Top', 'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.8
# frozenset({'Lab Top', 'Printer'}) => frozenset({'Microsoft Office'}) confidence:  0.8
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'Lab Top'}) confidence:  0.4444444444444445
# frozenset({'Lab Top'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.33333333333333337
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top', 'Printer'}) confidence:  0.36363636363636365
# frozenset({'Printer'}) => frozenset({'Lab Top', 'Microsoft Office'}) confidence:  0.4
# frozenset({'Lab Top Case', 'Desk Top'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Anti-Virus', 'Desk Top'}) => frozenset({'Lab Top Case'}) confidence:  0.7499999999999999
# frozenset({'Lab Top Case', 'Anti-Virus'}) => frozenset({'Desk Top'}) confidence:  0.25
# frozenset({'Desk Top'}) => frozenset({'Lab Top Case', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top Case', 'Desk Top'}) confidence:  0.2142857142857143
# frozenset({'Lab Top Case'}) => frozenset({'Desk Top', 'Anti-Virus'}) confidence:  0.2142857142857143
# frozenset({'Speakers', 'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.8333333333333334
# frozenset({'Printer', 'Speakers'}) => frozenset({'Microsoft Office'}) confidence:  1.0
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'Speakers'}) confidence:  0.5555555555555556
# frozenset({'Speakers'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.45454545454545453
# frozenset({'Microsoft Office'}) => frozenset({'Printer', 'Speakers'}) confidence:  0.45454545454545453
# frozenset({'Printer'}) => frozenset({'Speakers', 'Microsoft Office'}) confidence:  0.5
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'Anti-Virus'}) confidence:  0.6666666666666666
# frozenset({'Anti-Virus', 'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.7499999999999999
# frozenset({'Printer', 'Anti-Virus'}) => frozenset({'Microsoft Office'}) confidence:  0.8571428571428572
# frozenset({'Printer'}) => frozenset({'Microsoft Office', 'Anti-Virus'}) confidence:  0.6
# frozenset({'Anti-Virus'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.4285714285714286
# frozenset({'Microsoft Office'}) => frozenset({'Printer', 'Anti-Virus'}) confidence:  0.5454545454545454
# frozenset({'Lab Top Case', 'Microsoft Office'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Lab Top Case', 'Anti-Virus'}) => frozenset({'Microsoft Office'}) confidence:  0.5833333333333334
# frozenset({'Anti-Virus', 'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  0.8749999999999999
# frozenset({'Lab Top Case'}) => frozenset({'Microsoft Office', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top Case', 'Microsoft Office'}) confidence:  0.5
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top Case', 'Anti-Virus'}) confidence:  0.6363636363636362
# frozenset({'Microsoft Office', 'Desk Top'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Desk Top'}) => frozenset({'Microsoft Office'}) confidence:  1.0
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'Desk Top'}) confidence:  0.45454545454545453
# frozenset({'Desk Top'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.8333333333333334
# frozenset({'Flash Drive'}) => frozenset({'Desk Top', 'Microsoft Office'}) confidence:  0.3846153846153846
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'Desk Top'}) confidence:  0.45454545454545453
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'Microsoft Office'}) confidence:  0.5555555555555556
# frozenset({'Speakers', 'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  0.8333333333333334
# frozenset({'Lab Top Case', 'Microsoft Office'}) => frozenset({'Speakers'}) confidence:  0.7142857142857143
# frozenset({'Speakers'}) => frozenset({'Lab Top Case', 'Microsoft Office'}) confidence:  0.45454545454545453
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.45454545454545453
# frozenset({'Lab Top Case'}) => frozenset({'Speakers', 'Microsoft Office'}) confidence:  0.35714285714285715
# frozenset({'Speakers', 'External Hard-Drive'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Speakers', 'Anti-Virus'}) => frozenset({'External Hard-Drive'}) confidence:  0.6666666666666666
# frozenset({'Anti-Virus', 'External Hard-Drive'}) => frozenset({'Speakers'}) confidence:  0.6666666666666666
# frozenset({'Speakers'}) => frozenset({'External Hard-Drive', 'Anti-Virus'}) confidence:  0.5454545454545454
# frozenset({'External Hard-Drive'}) => frozenset({'Speakers', 'Anti-Virus'}) confidence:  0.6666666666666666
# frozenset({'Anti-Virus'}) => frozenset({'Speakers', 'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'Lab Top', 'External Hard-Drive'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Lab Top', 'Anti-Virus'}) => frozenset({'External Hard-Drive'}) confidence:  0.6
# frozenset({'Anti-Virus', 'External Hard-Drive'}) => frozenset({'Lab Top'}) confidence:  0.6666666666666666
# frozenset({'Lab Top'}) => frozenset({'External Hard-Drive', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top', 'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top', 'Anti-Virus'}) confidence:  0.6666666666666666
# frozenset({'Lab Top Case', 'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.7142857142857143
# frozenset({'Lab Top Case', 'Printer'}) => frozenset({'Microsoft Office'}) confidence:  0.8333333333333334
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  0.5555555555555556
# frozenset({'Lab Top Case'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.35714285714285715
# frozenset({'Printer'}) => frozenset({'Lab Top Case', 'Microsoft Office'}) confidence:  0.5
# frozenset({'Microsoft Office'}) => frozenset({'Lab Top Case', 'Printer'}) confidence:  0.45454545454545453
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'Printer'}) confidence:  0.8181818181818181
# frozenset({'Printer', 'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'Microsoft Office'}) confidence:  0.9
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.9
# frozenset({'Flash Drive'}) => frozenset({'Printer', 'Microsoft Office'}) confidence:  0.6923076923076923
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.8181818181818181
# frozenset({'Speakers', 'Digital Camera'}) => frozenset({'Microsoft Office'}) confidence:  0.4285714285714286
# frozenset({'Speakers', 'Microsoft Office'}) => frozenset({'Digital Camera'}) confidence:  0.5
# frozenset({'Digital Camera', 'Microsoft Office'}) => frozenset({'Speakers'}) confidence:  0.7499999999999999
# frozenset({'Speakers'}) => frozenset({'Digital Camera', 'Microsoft Office'}) confidence:  0.2727272727272727
# frozenset({'Microsoft Office'}) => frozenset({'Speakers', 'Digital Camera'}) confidence:  0.2727272727272727
# frozenset({'Digital Camera'}) => frozenset({'Speakers', 'Microsoft Office'}) confidence:  0.3333333333333333
# frozenset({'Lab Top Case', 'Digital Camera'}) => frozenset({'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'Digital Camera', 'External Hard-Drive'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'Lab Top Case', 'External Hard-Drive'}) => frozenset({'Digital Camera'}) confidence:  0.37499999999999994
# frozenset({'Digital Camera'}) => frozenset({'Lab Top Case', 'External Hard-Drive'}) confidence:  0.3333333333333333
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top Case', 'Digital Camera'}) confidence:  0.3333333333333333
# frozenset({'Lab Top Case'}) => frozenset({'Digital Camera', 'External Hard-Drive'}) confidence:  0.2142857142857143
# frozenset({'Lab Top', 'Microsoft Office'}) => frozenset({'Anti-Virus'}) confidence:  0.8
# frozenset({'Lab Top', 'Anti-Virus'}) => frozenset({'Microsoft Office'}) confidence:  0.4
# frozenset({'Anti-Virus', 'Microsoft Office'}) => frozenset({'Lab Top'}) confidence:  0.5
# ...
# frozenset({'Digital Camera'}) => frozenset({'Lab Top Case', 'Anti-Virus'}) confidence:  0.5555555555555556
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top Case', 'Digital Camera'}) confidence:  0.35714285714285715
# frozenset({'Printer', 'Lab Top Case'}) => frozenset({'External Hard-Drive'}) confidence:  0.8333333333333334
# frozenset({'Lab Top Case', 'External Hard-Drive'}) => frozenset({'Printer'}) confidence:  0.625
# frozenset({'Printer', 'External Hard-Drive'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'Lab Top Case'}) => frozenset({'Printer', 'External Hard-Drive'}) confidence:  0.35714285714285715
# frozenset({'Printer'}) => frozenset({'Lab Top Case', 'External Hard-Drive'}) confidence:  0.5
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top Case', 'Printer'}) confidence:  0.5555555555555556
# frozenset({'Flash Drive', 'Lab Top'}) => frozenset({'Anti-Virus'}) confidence:  0.8571428571428572
# frozenset({'Lab Top', 'Anti-Virus'}) => frozenset({'Flash Drive'}) confidence:  0.6
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'Lab Top'}) confidence:  0.6
# frozenset({'Lab Top'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'Lab Top'}) confidence:  0.4285714285714286
# frozenset({'Flash Drive'}) => frozenset({'Lab Top', 'Anti-Virus'}) confidence:  0.4615384615384615
# frozenset({'Lab Top', 'Digital Camera'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'Lab Top', 'Lab Top Case'}) => frozenset({'Digital Camera'}) confidence:  0.5
# frozenset({'Lab Top Case', 'Digital Camera'}) => frozenset({'Lab Top'}) confidence:  0.7142857142857143
# frozenset({'Lab Top Case'}) => frozenset({'Lab Top', 'Digital Camera'}) confidence:  0.35714285714285715
# frozenset({'Digital Camera'}) => frozenset({'Lab Top', 'Lab Top Case'}) confidence:  0.5555555555555556
# frozenset({'Lab Top'}) => frozenset({'Lab Top Case', 'Digital Camera'}) confidence:  0.4166666666666667
# frozenset({'Flash Drive', 'Speakers'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Speakers', 'Anti-Virus'}) => frozenset({'Flash Drive'}) confidence:  0.6666666666666666
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'Speakers'}) confidence:  0.6
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'Speakers'}) confidence:  0.4285714285714286
# frozenset({'Flash Drive'}) => frozenset({'Speakers', 'Anti-Virus'}) confidence:  0.4615384615384615
# frozenset({'Speakers'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.5454545454545454
# frozenset({'Speakers', 'Desk Top'}) => frozenset({'Printer'}) confidence:  0.7499999999999999
# frozenset({'Printer', 'Speakers'}) => frozenset({'Desk Top'}) confidence:  0.6
# frozenset({'Printer', 'Desk Top'}) => frozenset({'Speakers'}) confidence:  0.6
# frozenset({'Printer'}) => frozenset({'Speakers', 'Desk Top'}) confidence:  0.3
# frozenset({'Desk Top'}) => frozenset({'Printer', 'Speakers'}) confidence:  0.5
# frozenset({'Speakers'}) => frozenset({'Printer', 'Desk Top'}) confidence:  0.2727272727272727
# frozenset({'Speakers', 'Desk Top'}) => frozenset({'Lab Top Case'}) confidence:  0.7499999999999999
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'Desk Top'}) confidence:  0.3333333333333333
# frozenset({'Lab Top Case', 'Desk Top'}) => frozenset({'Speakers'}) confidence:  1.0
# frozenset({'Lab Top Case'}) => frozenset({'Speakers', 'Desk Top'}) confidence:  0.2142857142857143
# frozenset({'Desk Top'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.5
# frozenset({'Speakers'}) => frozenset({'Lab Top Case', 'Desk Top'}) confidence:  0.2727272727272727
# frozenset({'Printer', 'Lab Top Case'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Lab Top Case', 'Anti-Virus'}) => frozenset({'Printer'}) confidence:  0.5
# frozenset({'Printer', 'Anti-Virus'}) => frozenset({'Lab Top Case'}) confidence:  0.8571428571428572
# frozenset({'Lab Top Case'}) => frozenset({'Printer', 'Anti-Virus'}) confidence:  0.4285714285714286
# frozenset({'Printer'}) => frozenset({'Lab Top Case', 'Anti-Virus'}) confidence:  0.6
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top Case', 'Printer'}) confidence:  0.4285714285714286
# frozenset({'Lab Top', 'Digital Camera'}) => frozenset({'Anti-Virus'}) confidence:  0.8
# frozenset({'Lab Top', 'Anti-Virus'}) => frozenset({'Digital Camera'}) confidence:  0.4
# frozenset({'Digital Camera', 'Anti-Virus'}) => frozenset({'Lab Top'}) confidence:  0.8
# frozenset({'Lab Top'}) => frozenset({'Digital Camera', 'Anti-Virus'}) confidence:  0.33333333333333337
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top', 'Digital Camera'}) confidence:  0.28571428571428575
# frozenset({'Digital Camera'}) => frozenset({'Lab Top', 'Anti-Virus'}) confidence:  0.4444444444444445
# frozenset({'Flash Drive', 'Desk Top'}) => frozenset({'Printer'}) confidence:  1.0
# frozenset({'Printer', 'Desk Top'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'Desk Top'}) confidence:  0.5
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'Desk Top'}) confidence:  0.5
# frozenset({'Desk Top'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.8333333333333334
# frozenset({'Flash Drive'}) => frozenset({'Printer', 'Desk Top'}) confidence:  0.3846153846153846
# frozenset({'Lab Top', 'Speakers'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Lab Top', 'Anti-Virus'}) => frozenset({'Speakers'}) confidence:  0.5
# frozenset({'Speakers', 'Anti-Virus'}) => frozenset({'Lab Top'}) confidence:  0.5555555555555556
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top', 'Speakers'}) confidence:  0.35714285714285715
# frozenset({'Lab Top'}) => frozenset({'Speakers', 'Anti-Virus'}) confidence:  0.4166666666666667
# frozenset({'Speakers'}) => frozenset({'Lab Top', 'Anti-Virus'}) confidence:  0.45454545454545453
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'Anti-Virus'}) confidence:  0.7
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'Printer'}) confidence:  0.7
# frozenset({'Printer', 'Anti-Virus'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive'}) => frozenset({'Printer', 'Anti-Virus'}) confidence:  0.5384615384615384
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.5
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.7
# frozenset({'Flash Drive', 'Lab Top Case'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Lab Top Case', 'Anti-Virus'}) => frozenset({'Flash Drive'}) confidence:  0.75
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'Lab Top Case'}) confidence:  0.9
# frozenset({'Flash Drive'}) => frozenset({'Lab Top Case', 'Anti-Virus'}) confidence:  0.6923076923076923
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'Lab Top Case'}) confidence:  0.6428571428571429
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.6428571428571429
# frozenset({'Lab Top', 'Lab Top Case'}) => frozenset({'Anti-Virus'}) confidence:  0.9
# frozenset({'Lab Top', 'Anti-Virus'}) => frozenset({'Lab Top Case'}) confidence:  0.9
# frozenset({'Lab Top Case', 'Anti-Virus'}) => frozenset({'Lab Top'}) confidence:  0.75
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top', 'Lab Top Case'}) confidence:  0.6428571428571429
# frozenset({'Lab Top'}) => frozenset({'Lab Top Case', 'Anti-Virus'}) confidence:  0.75
# frozenset({'Lab Top Case'}) => frozenset({'Lab Top', 'Anti-Virus'}) confidence:  0.6428571428571429
# frozenset({'Lab Top', 'Printer'}) => frozenset({'Anti-Virus'}) confidence:  0.8
# frozenset({'Lab Top', 'Anti-Virus'}) => frozenset({'Printer'}) confidence:  0.4
# frozenset({'Printer', 'Anti-Virus'}) => frozenset({'Lab Top'}) confidence:  0.5714285714285715
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top', 'Printer'}) confidence:  0.28571428571428575
# frozenset({'Lab Top'}) => frozenset({'Printer', 'Anti-Virus'}) confidence:  0.33333333333333337
# frozenset({'Printer'}) => frozenset({'Lab Top', 'Anti-Virus'}) confidence:  0.4
# frozenset({'Speakers', 'Desk Top'}) => frozenset({'Flash Drive'}) confidence:  0.7499999999999999
# frozenset({'Flash Drive', 'Speakers'}) => frozenset({'Desk Top'}) confidence:  0.5
# frozenset({'Flash Drive', 'Desk Top'}) => frozenset({'Speakers'}) confidence:  0.6
# frozenset({'Flash Drive'}) => frozenset({'Speakers', 'Desk Top'}) confidence:  0.23076923076923075
# frozenset({'Desk Top'}) => frozenset({'Flash Drive', 'Speakers'}) confidence:  0.5
# frozenset({'Speakers'}) => frozenset({'Flash Drive', 'Desk Top'}) confidence:  0.2727272727272727
# frozenset({'Speakers', 'Digital Camera'}) => frozenset({'Flash Drive'}) confidence:  0.4285714285714286
# frozenset({'Flash Drive', 'Speakers'}) => frozenset({'Digital Camera'}) confidence:  0.5
# frozenset({'Flash Drive', 'Digital Camera'}) => frozenset({'Speakers'}) confidence:  0.7499999999999999
# frozenset({'Speakers'}) => frozenset({'Flash Drive', 'Digital Camera'}) confidence:  0.2727272727272727
# frozenset({'Flash Drive'}) => frozenset({'Speakers', 'Digital Camera'}) confidence:  0.23076923076923075
# frozenset({'Digital Camera'}) => frozenset({'Flash Drive', 'Speakers'}) confidence:  0.3333333333333333
# frozenset({'Printer', 'Speakers'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Speakers', 'Anti-Virus'}) => frozenset({'Printer'}) confidence:  0.5555555555555556
# frozenset({'Printer', 'Anti-Virus'}) => frozenset({'Speakers'}) confidence:  0.7142857142857143
# frozenset({'Anti-Virus'}) => frozenset({'Printer', 'Speakers'}) confidence:  0.35714285714285715
# frozenset({'Speakers'}) => frozenset({'Printer', 'Anti-Virus'}) confidence:  0.45454545454545453
# frozenset({'Printer'}) => frozenset({'Speakers', 'Anti-Virus'}) confidence:  0.5
# frozenset({'Lab Top Case', 'Speakers'}) => frozenset({'Anti-Virus'}) confidence:  0.888888888888889
# frozenset({'Speakers', 'Anti-Virus'}) => frozenset({'Lab Top Case'}) confidence:  0.888888888888889
# frozenset({'Lab Top Case', 'Anti-Virus'}) => frozenset({'Speakers'}) confidence:  0.6666666666666667
# frozenset({'Anti-Virus'}) => frozenset({'Lab Top Case', 'Speakers'}) confidence:  0.5714285714285715
# frozenset({'Speakers'}) => frozenset({'Lab Top Case', 'Anti-Virus'}) confidence:  0.7272727272727273
# frozenset({'Lab Top Case'}) => frozenset({'Speakers', 'Anti-Virus'}) confidence:  0.5714285714285715
# frozenset({'Digital Camera', 'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Digital Camera'}) => frozenset({'Microsoft Office'}) confidence:  1.0
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'Digital Camera'}) confidence:  0.36363636363636365
# frozenset({'Digital Camera'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.4444444444444445
# frozenset({'Flash Drive'}) => frozenset({'Digital Camera', 'Microsoft Office'}) confidence:  0.3076923076923077
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'Digital Camera'}) confidence:  0.36363636363636365
# frozenset({'Microsoft Office', 'External Hard-Drive'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Anti-Virus', 'Microsoft Office'}) => frozenset({'External Hard-Drive'}) confidence:  0.625
# frozenset({'Anti-Virus', 'External Hard-Drive'}) => frozenset({'Microsoft Office'}) confidence:  0.5555555555555556
# frozenset({'External Hard-Drive'}) => frozenset({'Microsoft Office', 'Anti-Virus'}) confidence:  0.5555555555555556
# frozenset({'Microsoft Office'}) => frozenset({'External Hard-Drive', 'Anti-Virus'}) confidence:  0.45454545454545453
# frozenset({'Anti-Virus'}) => frozenset({'Microsoft Office', 'External Hard-Drive'}) confidence:  0.35714285714285715
# frozenset({'Digital Camera', 'External Hard-Drive'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Digital Camera', 'Anti-Virus'}) => frozenset({'External Hard-Drive'}) confidence:  0.6
# frozenset({'Anti-Virus', 'External Hard-Drive'}) => frozenset({'Digital Camera'}) confidence:  0.3333333333333333
# frozenset({'Digital Camera'}) => frozenset({'External Hard-Drive', 'Anti-Virus'}) confidence:  0.3333333333333333
# frozenset({'External Hard-Drive'}) => frozenset({'Digital Camera', 'Anti-Virus'}) confidence:  0.3333333333333333
# frozenset({'Anti-Virus'}) => frozenset({'Digital Camera', 'External Hard-Drive'}) confidence:  0.2142857142857143
# frozenset({'Flash Drive', 'Printer'}) => frozenset({'External Hard-Drive'}) confidence:  0.5
# frozenset({'Flash Drive', 'External Hard-Drive'}) => frozenset({'Printer'}) confidence:  0.8333333333333334
# frozenset({'Printer', 'External Hard-Drive'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive'}) => frozenset({'Printer', 'External Hard-Drive'}) confidence:  0.3846153846153846
# frozenset({'External Hard-Drive'}) => frozenset({'Flash Drive', 'Printer'}) confidence:  0.5555555555555556
# frozenset({'Printer'}) => frozenset({'Flash Drive', 'External Hard-Drive'}) confidence:  0.5
# frozenset({'Flash Drive', 'Lab Top Case'}) => frozenset({'External Hard-Drive'}) confidence:  0.6666666666666666
# frozenset({'Lab Top Case', 'External Hard-Drive'}) => frozenset({'Flash Drive'}) confidence:  0.7499999999999999
# frozenset({'Flash Drive', 'External Hard-Drive'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'Flash Drive'}) => frozenset({'Lab Top Case', 'External Hard-Drive'}) confidence:  0.4615384615384615
# frozenset({'External Hard-Drive'}) => frozenset({'Flash Drive', 'Lab Top Case'}) confidence:  0.6666666666666666
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive', 'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'Lab Top Case', 'Desk Top'}) => frozenset({'External Hard-Drive'}) confidence:  1.0
# frozenset({'Desk Top', 'External Hard-Drive'}) => frozenset({'Lab Top Case'}) confidence:  1.0
# frozenset({'Lab Top Case', 'External Hard-Drive'}) => frozenset({'Desk Top'}) confidence:  0.37499999999999994
# frozenset({'Desk Top'}) => frozenset({'Lab Top Case', 'External Hard-Drive'}) confidence:  0.5
# frozenset({'External Hard-Drive'}) => frozenset({'Lab Top Case', 'Desk Top'}) confidence:  0.3333333333333333
# frozenset({'Lab Top Case'}) => frozenset({'Desk Top', 'External Hard-Drive'}) confidence:  0.2142857142857143
# frozenset({'Flash Drive', 'External Hard-Drive'}) => frozenset({'Anti-Virus'}) confidence:  1.0
# frozenset({'Flash Drive', 'Anti-Virus'}) => frozenset({'External Hard-Drive'}) confidence:  0.6
# frozenset({'Anti-Virus', 'External Hard-Drive'}) => frozenset({'Flash Drive'}) confidence:  0.6666666666666666
# frozenset({'Flash Drive'}) => frozenset({'External Hard-Drive', 'Anti-Virus'}) confidence:  0.4615384615384615
# frozenset({'Anti-Virus'}) => frozenset({'Flash Drive', 'External Hard-Drive'}) confidence:  0.4285714285714286
# frozenset({'External Hard-Drive'}) => frozenset({'Flash Drive', 'Anti-Virus'}) confidence:  0.6666666666666666
# frozenset({'Speakers', 'Desk Top'}) => frozenset({'Microsoft Office'}) confidence:  0.7499999999999999
# frozenset({'Speakers', 'Microsoft Office'}) => frozenset({'Desk Top'}) confidence:  0.5
# frozenset({'Microsoft Office', 'Desk Top'}) => frozenset({'Speakers'}) confidence:  0.6
# frozenset({'Speakers'}) => frozenset({'Desk Top', 'Microsoft Office'}) confidence:  0.2727272727272727
# frozenset({'Microsoft Office'}) => frozenset({'Speakers', 'Desk Top'}) confidence:  0.2727272727272727
# frozenset({'Desk Top'}) => frozenset({'Speakers', 'Microsoft Office'}) confidence:  0.5
# frozenset({'Lab Top Case', 'Microsoft Office'}) => frozenset({'Flash Drive'}) confidence:  1.0
# frozenset({'Flash Drive', 'Lab Top Case'}) => frozenset({'Microsoft Office'}) confidence:  0.7777777777777777
# frozenset({'Flash Drive', 'Microsoft Office'}) => frozenset({'Lab Top Case'}) confidence:  0.6363636363636362
# frozenset({'Lab Top Case'}) => frozenset({'Flash Drive', 'Microsoft Office'}) confidence:  0.5
# frozenset({'Flash Drive'}) => frozenset({'Lab Top Case', 'Microsoft Office'}) confidence:  0.5384615384615384
# frozenset({'Microsoft Office'}) => frozenset({'Flash Drive', 'Lab Top Case'}) confidence:  0.6363636363636362
